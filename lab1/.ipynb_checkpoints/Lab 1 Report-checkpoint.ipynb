# %% [markdown]
# # Lab 1 Report
#
# Charles Tung Fang

# %%
# %matplotlib notebook
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import simpleaudio as sa

# %% [markdown]
# ## Summary
# This lab is an introductory of python. It begins with fundamental rrays operation

# %% [markdown]
# ## Assignment 1 -- Creating and Manipulating Arrays

# %%
# Assignment 1 - Creating and Manipulating Arrays (Title of Assignment 1)

# Part A
y1 = np.array([4, 6, 2])

# Part B
ca = y1[1]
cb = y1[1:3]
d = len(y1)
print(ca, cb, d)

# Part C
x1 = np.ones(5) * 2
x2 = np.arange(-2, 3, 1)
print(x1, x2)

# Part D
arrp = x1 + x2
arrc = np.concatenate([x1, x2])
print(arrp, arrc)
# Out:
# 6 [6 2] 3
# [2. 2. 2. 2. 2.] [-2 -1  0  1  2]
# [0. 1. 2. 3. 4.] [ 2.  2.  2.  2.  2. -2. -1.  0.  1.  2.]

# %% [markdown]
# ### Discussion
# Concatenation combine arrays together to one result array which its length is the sum of the length of each arrays that's concatenated.
# Addition sum up the values of arrays that have same length into a result array that has a same length.

# %% [markdown]
# ## Assignment 2: Amplitude Operations on Signals

# %%
# Assignment 2 - Amplitude Operations on Signals

# t = numpy.arange(start, stop, ts) # ts = sampling period (step size)

# Part A
fs = 2
t = np.arange(0, 3.5, 1/fs)
x = t * 0.5
y = t * t 

# Part B
z = x - 2 * y

# Part C
nt = int(2*fs)
nstart = int(0*fs)
w1 = z[nt-nstart]
print(w1) 

# Part D
n2 = int(1.5*fs)
w2 = z[nstart : nstart - n2]
print(w2)
# Out:
# -7.0
# [ 0.   -0.25 -1.5  -3.75]

# %% [markdown]
# ### Discussion
# fs = 1 has a lower frequency and means a smaller step size and less samplings are kept track of. Because the frequency is cut by half, it results the length in x, y, and z also decrease by half. In addition, the length of w2 will shrink by half to 2 instead of 4. However, the result of w1 stays the same since we're only taking one value

# %% [markdown]
# ## Assignment 3 -- Working with Sound Files

# %%
# Assignment 3 - Working with Sound Files

# Part A
from scipy.io import wavfile as wav
fs1, y1 = wav.read('train32.wav')
fs2, y2 = wav.read('tuba11.wav')
ch1 = len(y1.shape)
len2, ch2 = y2.shape
print(ch1,ch2)

# Part B
wav_obj1 = sa.WaveObject.from_wave_file('train32.wav')
wav_obj2 = sa.WaveObject.from_wave_file('tuba11.wav')
play_train1 = wav_obj1.play()
play_train1.wait_done()
play_tuba1 = wav_obj2.play()
play_tuba1.wait_done()
play_train2 = sa.play_buffer(y1, ch1, 2, fs2)
play_train2.wait_done()
play_tuba2 = sa.play_buffer(y2, ch2, 2, fs1)
play_tuba2.wait_done()

# Part C
y2 = y2[:,1]
length1 = len(y1)
length2 = len(y2)
if (length1 >= length2): 
    y3 = y1[0:length2]
    y4 = 0.7*y3 + 0.7*y2
else :
    y3 = y2[0:length1]
    y4 = 0.7*y3 + 0.7*y1
y4 = np.int16(y4)
play_obj3 = sa.play_buffer(y4, ch1, 2, fs1)
play_obj3.wait_done()
outfile = 'y4.wav'
wav.write(outfile,fs1,y4.astype('int16'))

# Part D
pause = np.zeros(4*fs,dtype=np.int16)
y5 = np.concatenate([y1, pause, y2])
play_obj4 = sa.play_buffer(y5, ch1, 2, fs1)
play_obj4.wait_done()
outfile = 'y5.wav'
wav.write(outfile, fs1, y5.astype('int16'))
# Out:
# 1 2

# %% [markdown]
# ### Discussion
# When the incorrect frequency is used, the playing speed of the audio changes faster or slower depending on whether the frequecny is a higher frequency or a lower frequency. In addition, a lower pitch is heard when a lower frequncey is used. On the other hand, a higher picth is heard when a higher frequency is used. Due to tuba sound is stereo, we had to extract it to one chanel before we add or concatenate it with train sound in parts C and D.

# %% [markdown]
# ## Assignment 4 -- Plotting Comparisons

# %%
# Assignment 4

# Part A
t = np.arange(-2,4.1, 0.2)
fs = 5
w = abs(t)
x = 2 - t
y = -0.5 * t * t

# Part B
fig1 = plt.figure(1)

plt.plot(t, w, label = 'w(t)')
plt.plot(t, x, label = 'x(t)')
plt.plot(t, y, label = 'y(t)')
plt.xlabel('t')
plt.suptitle("Comparison Plot")
plt.legend()
plt.show()
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Discussion
# We can change the linestyle of each signal to make figure easier to read for someone who is color blind. For example we can seperate them into solid, dashed dotted by writing

# %% [markdown]
# ## Assignment 5 -- Plotting Sound Files in Subplots

# %%
# Assignment 5 -- Plotting Sound Files using Subplots

# Part A
from scipy.io import wavfile as wav
fs1, y1 = wav.read('train32.wav')
fs2, y2 = wav.read('tuba11.wav')
t1 = np.arange(0, len(y1), 1)
t1 = t1 / fs1 * 1000
t2 = np.arange(0, len(y2), 1)
t2 = t2 / fs2 * 1000

# Part B
fig2 = plt.figure(2)
fig2.subplots_adjust(hspace = 0.5, wspace = 0.7)

plt.subplot(1, 2, 1)
plt.plot(t1, y1, color = 'purple')
plt.title('y1')
plt.ylim(-30000, 30000)
plt.xlim(0, 2500)
plt.ylabel('Amplitude')
plt.xlabel('Time(ms)')

plt.subplot(1, 2, 2)
plt.plot(t2, y2, color = 'gold')
plt.title('y2')
plt.ylim(-30000, 30000)
plt.xlim(0, 2500)
plt.ylabel('Amplitude')
plt.xlabel('Time(ms)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Discussion
# The difference between two signals are their amplitude and lenght. Not able to see the difference in sampling rate because the scope is too big.
